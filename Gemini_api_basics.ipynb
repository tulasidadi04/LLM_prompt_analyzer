# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path=r'C:\Users\sampa\OneDrive\Desktop\LLM_prompt_analyzer\.env')
API_KEY=os.getenv("GEMINI_API_KEY")

client=genai.Client(api_key=API_KEY)

prompt="what is the age of rohit sharma"

response=client.models.generate_content(

    model="gemini-2.5-flash",
    contents=prompt
)

print(response.text)
# Out:
# Rohit Sharma was born on **April 30, 1987**.
#
# As of today (late 2023 / early 2024), he is **36 years old**. He will turn 37 on April 30, 2024.

# %%
print("Hey i am LLM")
# Out:
# Hey i am LLM
