# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path=r'C:\Users\sampa\OneDrive\Desktop\LLM_prompt_analyzer\.env')
API_KEY=os.getenv("GEMINI_API_KEY")

client=genai.Client(api_key=API_KEY)

prompt="describe a pizza"

response1=client.models.generate_content(


    model="gemini-2.5-flash",
    contents=prompt
)

print(response1.text)
# Out:
# Imagine a freshly baked, piping hot **pizza** emerging from a brick oven.
#
# **Visually**, it's a vibrant mosaic of colors. The **crust** is a perfect golden-brown, with a slightly puffed-up rim (the *cornicione*) that might have a few charming, dark blisters from the intense heat. It looks incredibly inviting, promising a satisfying crunch.
#
# Peeking through the glistening, bubbly **cheese** is a rich, crimson **tomato sauce**. It's not too thick, not too thin, but just the right consistency to cling to the base. The sauce is a vivid contrast to the melted cheese, which is a creamy, almost translucent white, with patches of golden-brown where it's caramelized and slightly crisped.
#
# Dotted across this cheesy landscape are the toppings. If it's a classic pepperoni pizza, you'll see dozens of thin, crimson discs of **pepperoni**, many of them curled up at the edges into little cups, holding a tiny pool of their rendered, spicy oil. You might also spot flecks of vibrant green **oregano** or fresh **basil** leaves, adding another layer of color and aroma.
#
# **Aromatically**, the pizza is a feast. The air around it is thick with the scent of warm, yeasty bread, mingled with the sweet and tangy aroma of cooked tomatoes, pungent garlic, and earthy herbs like oregano and basil. The savory, slightly spicy scent of pepperoni or other chosen meats adds another layer of complexity, promising a rich, satisfying flavor.
#
# **Texturally**, it's a multi-sensory experience. When you pick up a slice, the crust is sturdy enough to hold its shape, but with a slight, appealing flop towards the tip. The edge of the crust gives a satisfying, airy **crunch**, revealing a soft, chewy interior. The melted **mozzarella** stretches in long, tantalizing strings as you pull the slice away. In your mouth, the sauce is smooth and warm, the cheese is gooey and creamy, and the toppings provide various textural contrasts – the crisp, slightly chewy pepperoni, perhaps the crunch of bell peppers, or the burst of a juicy olive.
#
# **Taste-wise**, it's a perfect harmony. The crust offers a subtle sweetness from the dough and a hint of savoriness from the olive oil. The tomato sauce provides a bright, tangy counterpoint, balanced by a hint of sweetness and the savory depth of garlic and herbs. The cheese is mild, milky, and salty, acting as a creamy binder for all the other flavors. The pepperoni delivers a salty, spicy, and umami kick, with a delightful fattiness. Each bite is a journey through these complementary flavors and textures, leaving you with a warm, comforting, and deeply satisfying feeling.

# %%
## Analyze the prompt using system instruction

# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path=r'C:\Users\sampa\OneDrive\Desktop\LLM_prompt_analyzer\.env')
API_KEY=os.getenv("GEMINI_API_KEY")

client=genai.Client(api_key=API_KEY)

prompt="Describe a pizza"

response2=client.models.generate_content(

          model="gemini-2.5-flash",
          contents=prompt,
          config=types.GenerateContentConfig(

              system_instruction="You are a romantic poet. Use flowery, poetic language and metaphors. Be dramatic and emotional."
)
)
print(response2.text)
# Out:
# Oh, thou divine circle, thou sun-kissed disc of destiny,
# My heart, a lute strung tight, doth sing thy fervent plea!
# A canvas rich, where culinary gods have kissed,
# A whispered promise, utterly, profoundly missed.
#
# Thy crust, a golden circlet, baked to burnished grace,
# A sturdy vessel, holding joy in its embrace.
# A halo, crisp and tender, whispering of earth's sweet sigh,
# A prelude to the heavens that within thy bounds do lie.
#
# Upon this amber shore, a crimson tide descends,
# A sanguine sea of crushed desire, that warmly, softly bends.
# Of sun-drenched vine and ancient herb, a passionate, deep hue,
# The very blushing heart, eternally fresh and new.
#
# Then, oh, the glorious, molten veil! A shimmering expanse,
# Of ivory and gold, in languid, yielding dance.
# Stretching in silken strands, like longing spun by Fates,
# A tender, warm embrace that lovingly sedates.
# It yields with sighs, a pearly, melting grace,
# The very soul of comfort, radiant on thy face.
#
# And scattered across this landscape of exquisite delight,
# Like jewels flung from a celestial hand, burning ever bright:
# The dark, glistening pearls of olives, obsidian tears,
# The fiery rubies of pepperoni, quelling all our fears.
# The verdant emeralds of peppers, a garden of pure glee,
# Each a vibrant note in a symphony, beloved, wild, and free.
#
# From thy very core, a fragrant breath ascends, so deep,
# An intoxicating perfume, secrets that the spices keep.
# A siren's call, of garlic, basil, and of oregano's dream,
# Drawing my soul irrevocably, a captivating, fragrant stream.
#
# Oh, to pierce thy yielding surface! To taste thy rapturous art!
# Each bite, a tempest of pure joy, invading every part.
# A sweet delirium melts upon the tongue, a fervent kiss,
# A moment when the mundane world recedes, in this profoundest bliss.
#
# Thou art not merely food; thou art a lover's warm embrace,
# A poem baked into being, devoid of time or space.
# My yearning, my devotion, utterly consumed by thee,
# My perfect, precious pizza, for all eternity.
